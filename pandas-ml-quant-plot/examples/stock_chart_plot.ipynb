# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from pandas_ml_quant import pd
import pandas_ml_quant_plot
from pandas_ml_quant_plot.plot_utils import color_positive_negative
# Out:
# automatically imported pandas_ml_quant_data_provider 0.2.0
# automatically imported pandas_ml_quant_plot 0.2.0

# %%
df = pd.read_csv("../pandas_ml_quant_plot_test/.data/SPY.csv", index_col="Date", parse_dates=True)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-11-29  314.859985  315.130005  314.059998  314.309998  314.309998
# 2019-12-02  314.589996  314.660004  311.170013  311.640015  311.640015
# 2019-12-03  308.649994  309.640015  307.130005  309.549988  309.549988
# 2019-12-04  310.700012  312.119995  310.320007  311.459991  311.459991
# 2019-12-05  312.230011  312.250000  310.580109  312.089996  312.089996
#
#               Volume
# Date
# 2019-11-29  36592700
# 2019-12-02  75767800
# 2019-12-03  73941700
# 2019-12-04  49080000
# 2019-12-05  40781669

# %%
with df.ta_plot(range_slider_price='Close', backend='nbAgg') as p:
    p["main"].candlestick("Open", "High", "Low", "Close")
    p["main"].line(p.df["Close"])
    p["volume"].bar("Volume", colors=color_positive_negative(p.df))
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
with df.ta_plot() as p:
    p["main"].candlestick("Open", "High", "Low", "Close")
    p["main"].line(p.df["Close"].ta.sma(90))
    p["main"].line("Close")
    # p["volume"].bar("Volume")
    # p["macd"].plot(df["Close"].ta.macd(), "line", "line", "bar")
    # p > "dist"
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
# Out:
# False

# %%
# Out:
# exc_type: <class 'TypeError'>
# exc_value: '>' not supported between instances of 'PlotContext' and 'str'
# exc_traceback: <traceback object at 0x7fea56909370>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4e443e56cd65> in <module>
#       4     p["volume"].bar("Volume")
#       5     p["macd"].plot(df["Close"].ta.macd(), "line", "line", "bar")
# ----> 6     p > "dist"
#
# TypeError: '>' not supported between instances of 'PlotContext' and 'str'
