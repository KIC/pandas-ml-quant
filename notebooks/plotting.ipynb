# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import sys
import matplotlib.pyplot as plt
from pandas_ml_utils import FeaturesAndLabels
from pandas_ml_quant import pd, np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.fetch_yahoo("SPY")[-200:]
df.q.ta_plot()()
# Out:
# WARNING:pandas_ml_common.utils.index_utils:passed item was None

# %%
from mpldatacursor import datacursor
import matplotlib.pyplot as plt

p = df[-100:].q.ta_plot(figsize=(10, 6))
p.candlestick()
p.line(df[-100:]["Close"].q.ta_sma(period=20))
p.bar("Volume")
p.line(df[-100:]["Volume"].q.ta_sma(period=20), panel=1)

datacursor()
plt.show()
# Out:
# WARNING:py.warnings:/home/kic/projects/pandas-quant/pandas-ml-quant/pandas_ml_quant/df/plot.py:93: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.grid.tight_layout(self.fig)
#
# WARNING:pandas_ml_common.utils.index_utils:passed item was None

# %%
df.model.plot_features(
    FeaturesAndLabels(
        features=[
            lambda df: df["Close"].q.ta_macd(),
            lambda df: df["Close"].q.ta_rsi(),
            #lambda df: df["Close"].q.ta_week(),
            lambda df: df.q.ta_atr(),
            lambda df: df.q.ta_candles_as_culb(relative_close=True),
            #lambda df: df.q.ta_tr(),
            #lambda df: df.q.ta_williams_R(),
            #lambda df: df.q.ta_ultimate_osc(),
            #lambda df: df.q.ta_bop(),
            #lambda df: df.q.ta_cci(),
        ],
        labels=[
            #lambda df: (df["Close"] / df["Open"] - 1).shift(-1)
            lambda df: df["Close"].q.ta_future_bband_quantile(include_mean=True)
        ]
    )
)
# Out:
# WARNING:pandas_ml_common.utils.index_utils:passed item was None
# WARNING:pandas_ml_common.utils.index_utils:passed item was None
# <img src="data:image/png;base64,..." width="2612">
# WARNING:py.warnings:/usr/local/lib/python3.7/dist-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
#
# WARNING:py.warnings:/usr/local/lib/python3.7/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df["Close"].q.ta_rnn(24).q.ta_gaf()[-20:].q.ta_plot().plot_matrix_animation('Close_gaf')
# Out:
# <img src="data:image/png;base64,..." width="900">
# t:   0%|          | 0/20 [00:00<?, ?it/s, now=None]
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# t:  15%|█▌        | 3/20 [00:00<00:00, 21.07it/s, now=None]
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# t:  25%|██▌       | 5/20 [00:00<00:00, 18.55it/s, now=None]
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# t:  35%|███▌      | 7/20 [00:00<00:00, 16.67it/s, now=None]
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# t:  45%|████▌     | 9/20 [00:00<00:00, 15.52it/s, now=None]
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# t:  55%|█████▌    | 11/20 [00:00<00:00, 13.59it/s, now=None]
# <img src="data:image/png;base64,..." width="900">
# ...
