# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

try:
    import pandas_ml_quant
except Exception as e:
    from include_pycharm_modules import import_source_folders
    import_source_folders("/home/kic/sources/private/projects/pandas-quant")
    import pandas_ml_quant
    
print(pandas_ml_quant.__version__)

import matplotlib.pyplot as plt
from pandas_ta_quant import pd
from pandas_ta_quant_plot.plot_utils import color_positive_negative
from pandas_ta_quant_plot import Hist
# Out:
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-common
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-quant
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-utils
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-1ntegration-test
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-quant-data-provider
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-quant-rl
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-airflow
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-utils-torch
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ta-quant-plot
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ml-1ntegration-test-private
# adding module /home/kic/sources/private/projects/pandas-quant/pandas-ta-quant
# ...

# %%
df = pd.read_csv("../pandas_ta_quant_plot_test/.data/SPY.csv", index_col="Date", parse_dates=True)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-11-29  314.859985  315.130005  314.059998  314.309998  314.309998
# 2019-12-02  314.589996  314.660004  311.170013  311.640015  311.640015
# 2019-12-03  308.649994  309.640015  307.130005  309.549988  309.549988
# 2019-12-04  310.700012  312.119995  310.320007  311.459991  311.459991
# 2019-12-05  312.230011  312.250000  310.580109  312.089996  312.089996
#
#               Volume
# Date
# 2019-11-29  36592700
# 2019-12-02  75767800
# 2019-12-03  73941700
# 2019-12-04  49080000
# 2019-12-05  40781669

# %%
with df.ta.plot(range_slider_price='Close', backend='nbAgg', start=-120) as p:
    p["main"].candlestick("Open", "High", "Low", "Close")
    p["main"].line(p.df["Close"])
    p["volume"].bar("Volume", colors=color_positive_negative(p.df))
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
with df.ta.plot(range_slider_price='Close', backend='nbAgg') as p:
    p["main"].candlestick("Open", "High", "Low", "Close")
    p["main"].line(p.df["Close"]) > Hist(bins=100)
    p["volume"].bar("Volume", colors=color_positive_negative(p.df)) > Hist(bins=20)
# Out:
# <img src="data:image/png;base64,..." width="1440">
